# %% [markdown]
# # Lesson 1 - Phugoid Motion

# %% [markdown]
# $$\begin{eqnarray}
# L &=& C_L S \times \frac{1}{2} \rho v^2 \\
# D &=& C_D S \times \frac{1}{2} \rho v^2 \\ \\
# L &=& W \cos \gamma \\
# D &=& W \sin \gamma \\ \\
# \frac{z_t}{R} &=& \frac{1}{3} - \frac{C}{2}\sqrt{\frac{z_t^3}{z^3}}\\
# \end{eqnarray}$$

# %%
# %run phugoid.py
# %matplotlib inline

# %% [markdown]
# * Troichoidal-like path when $0 < C < \frac{2}{3}$

# %%
# Initital Conditions: zt = 64.0, z0 = 16.0, theta0 = 0.0
plot_flight_path(64.0, 16.0, 0.0)

# %% [markdown]
# * Series of loops when $C < 0$

# %%
# Initial Conditions: zt = 64.0, z0 = 16.0, theta0 = 180
plot_flight_path(64.0, 16.0, 180.0)

# %% [markdown]
# * Error when $C > \frac{2}{3}$ as it will result in $\cos \theta > 1$ which does not exist

# %% [markdown]
# * Series of semi-circles, with a cusp between them when $C=0$

# %%
# Initial Conditions: zt = 16.0, z0 = 48.0, theta0 = 0.0
plot_flight_path(16.0, 48.0, 0.0)

# %% [markdown]
# * Another configuration when C is (near) zero

# %%
# Initial Conditions: zt = 64.0, z0 = 16.0, theta0 = 90.0
plot_flight_path(64.0, 16.0, -90.0)
